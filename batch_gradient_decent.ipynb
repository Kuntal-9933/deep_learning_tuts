# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuntal-9933/deep_learning_tuts/blob/main/batch_gradient_decent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

# %%
df=pd.read_csv('https://raw.githubusercontent.com/codebasics/deep-learning-keras-tf-tutorial/master/6_gradient_descent/insurance_data.csv')
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
sns.pairplot(df)

# %%
x=df[['age','affordibility']]
y=df['bought_insurance']
x_val=x.copy()
x_val['age']=x_val['age']/100

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_val,y,train_size=0.9)

# %%
x_train.head()
# Out:
#      age  affordibility
# 0   0.22              1
# 2   0.47              1
# 16  0.25              0
# 20  0.21              1
# 26  0.23              1

# %%
model =keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train,y_train,epochs=5000)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5355 - accuracy: 0.9200
# Epoch 2502/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5355 - accuracy: 0.9200
# Epoch 2503/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5355 - accuracy: 0.9200
# Epoch 2504/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5354 - accuracy: 0.9200
# Epoch 2505/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5354 - accuracy: 0.9200
# Epoch 2506/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5353 - accuracy: 0.9200
# Epoch 2507/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5353 - accuracy: 0.9200
# Epoch 2508/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5352 - accuracy: 0.9200
# Epoch 2509/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5352 - accuracy: 0.9200
# Epoch 2510/5000
# ...

# %%
coef , bias = model.get_weights()
print(f"coefs are \nw1 :{coef[0]} \nw2 : {coef[1]} ")
print(f"bias is :{bias} ")
# Out:
# coefs are
# w1 :[5.1221423]
# w2 : [1.142413]
# bias is :[-2.8732183]

# %%
model.evaluate(x_test,y_test)
# Out:
# 1/1 [==============================] - 0s 128ms/step - loss: 0.3513 - accuracy: 1.0000
# [0.35128089785575867, 1.0]
